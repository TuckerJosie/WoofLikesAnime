# %% [markdown]
# <a href="https://colab.research.google.com/github/WoofLikesAnime/WoofLikesAnime/blob/main/Which_Authoritive_Figure_In_Pollard_Middle_School%2C_Needham%2C_Ma_Are_You%3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import matplotlib.pyplot as plt
from PIL import Image

Bibbo = Image.open("/6fc4e19d1edd1a4527663626f31f1daf~c5_100x100.jpeg")
Orlando = Image.open("/images (2) (1).jpg")
TheaterTeacherImage = Image.open("/images (3).jpg")

# Randomly select a number from the list (1, 2, 3)
random_number = random.choice([1, 2, 3])

if random_number == 1:
    print("You are Dr. Bibbo")  # Display text above the image
    plt.imshow(Bibbo)

elif random_number == 2:
    print("You are Mr. Orlando")  # Display text above the image
    plt.imshow(Orlando)

elif random_number == 3:
    print("You are the theater teacher (we couldn't find an image of exactly her, but here is the closest person who looks like her)")  # Display text above the image
    plt.imshow(TheaterTeacherImage)

plt.show()
# Out:
# You are the theater teacher (we couldn't find an image of exactly her, but here is the closest person who looks like her)
